# %%
# !python scripts/train.py --config configs/stage2.yaml && cp -r /content/2026-Text2Graph/pipeline/outputs/dreeam /content/drive/MyDrive/2026-Text2Graph/
# Out:
# Traceback (most recent call last):
#   File "/content/2026-Text2Graph/pipeline/scripts/train.py", line 40, in <module>
#     from src.utils import load_config, set_seed, save_checkpoint, load_checkpoint, count_parameters
#   File "/content/2026-Text2Graph/pipeline/src/__init__.py", line 21, in <module>
#     from .model import DocREModel
#   File "/content/2026-Text2Graph/pipeline/src/model.py", line 21, in <module>
#     from .graph_encoder import GraphEncoder, GraphUNetEncoder
# ImportError: cannot import name 'GraphUNetEncoder' from 'src.graph_encoder' (/content/2026-Text2Graph/pipeline/src/graph_encoder.py). Did you mean: 'GraphEncoder'?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/2026-Text2Graph /content/drive/MyDrive/

# 저장됐는지 확인
# !ls -d /content/drive/MyDrive/2026-Text2Graph
# %cd pipeline
# Out:
# /content/2026-Text2Graph/pipeline

# %%
# !git clone https://github.com/yeseul-kim01/2026-Text2Graph.git
# %cd 2026-Text2Graph
# !git checkout yeseul
# Out:
#   dev
# * yeseul

# %%
from .graph_encoder import GraphEncoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_17815/3834398590.py in <cell line: 0>()
# ----> 1 from .graph_encoder import GraphEncoder
#
# ImportError: attempted relative import with no known parent package
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !cp /content/2026-Text2Graph/pipeline/checkpoints/stage2/best_model.pt /content/drive/MyDrive/2026-Text2Graph/pipeline/checkpoints/stage2/
